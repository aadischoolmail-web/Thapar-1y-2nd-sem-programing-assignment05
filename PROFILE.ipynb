# %%
s1=set(map(int,input().split()))
print(s1)
# Out:
#  4 3 5
# {3, 4, 5}

# %%
s2 = {1,'a', 'letter'}
print(s2)
# Out:
# {'a', 1, 'letter'}

# %%
l1=[ 'chd', 'moh', 'pnk', 'chd']
s3=set(l1)
print(l1)
# Out:
# ['chd', 'moh', 'pnk', 'chd']

# %%
s4=set(input())
print(s4)
# Out:
#  abcd
# {'a', 'c', 'b', 'd'}

# %%
s = {2, 4, 6}
s.add(int(input()))
print(s)
# Out:
#  8
# {8, 2, 4, 6}

# %%
s = {1, 2}
s.update((3, 4))
print(s)
# Out:
# {1, 2, 3, 4}

# %%
s = {'a'}
s.update(input())
print(s)
# Out:
#  d gf
# {'a', ' ', 'd', 'g', 'f'}

# %%
s1, s2 = {1, 2}, {2, 3}
s1.update(s2)
print(s1)
# Out:
# {1, 2, 3}

# %%
def custom_update(s, data):
    if not hasattr(data, '__iter__'): raise TypeError("Not iterable")
    s.update(data)

# %%
s = {5, 10, 15}
s = {x for x in s if x >= 10}
print(s)
# Out:
# {10, 15}

# %%
langs = {"python", "java", "c"}
print(input() in langs)
# Out:
#  wf
# False

# %%
s = {1, 3, 4, 6}
s = {x for x in s if x % 3 != 0}
print(s)
# Out:
# {1, 4}

# %%
A, B = {1, 2}, {2, 3}
print(A|B, A&B, A-B, A^B)
# Out:
# {1, 2, 3} {2} {1} {1, 3}

# %%
m, p = {1, 2}, {2, 3}
print(m & p)
# Out:
# {2}

# %%
s1, s2 = {1, 2}, {2, 3}
print(s1 ^ s2)
# Out:
# {1, 3}

# %%
s1, s2 = {1, 2}, {3, 4}
print(s1.isdisjoint(s2))
# Out:
# True

# %%
A, B = {1}, {1, 2}
print(A.issubset(B), A.issuperset(B))
# Out:
# True False
